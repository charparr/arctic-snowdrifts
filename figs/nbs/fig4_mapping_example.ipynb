# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors

# %%
c = matplotlib.cm.get_cmap('Spectral')

# %%
gradient = np.linspace(0, 1, 256)
gradient = np.vstack((gradient, gradient))

# %%
fig, ax = plt.subplots(1, figsize=(16, 1))
fig.subplots_adjust(top=0.95, bottom=0.01, left=0.2, right=0.99)
ax.set_title('Snow Depth [$m$]', fontsize=32)
ax.imshow(gradient, aspect='auto', cmap=c)
ax.set_yticks([])
ax.set_xticks([0, 64, 128, 192, 255])
ax.set_xticklabels([0, 0.25, 0.5, 0.75, '>= 1.0'], fontsize=32)

plt.savefig('../spectral_0to1m_cbar.svg', bbox_inches='tight', dpi=600)
#x_text = pos[0] - 0.01
#y_text = pos[1] + pos[3]/2.
#fig.text(x_text, y_text, '1', va='center', ha='right', fontsize=10)

# %%
def plot_color_gradients(cmap_category, cmap_list, nrows):
    fig, axes = plt.subplots(nrows=nrows)
    fig.subplots_adjust(top=0.95, bottom=0.01, left=0.2, right=0.99)
    axes[0].set_title(cmap_category + ' colormaps', fontsize=14)

    for ax, name in zip(axes, cmap_list):
        ax.imshow(gradient, aspect='auto', cmap=plt.get_cmap(name))
        pos = list(ax.get_position().bounds)
        x_text = pos[0] - 0.01
        y_text = pos[1] + pos[3]/2.
        fig.text(x_text, y_text, name, va='center', ha='right', fontsize=10)

    # Turn off *all* ticks & spines, not just the ones with colormaps.
    for ax in axes:
        ax.set_axis_off()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-ebab90b8f6e8> in <module>
# ----> 1 plt.plot(c)
#
# ~/miniconda3/envs/rstr_vctr/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2785 @docstring.copy(Axes.plot)
#    2786 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2787     return gca().plot(
#    2788         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
#    2789         is not None else {}), **kwargs)
#
# ~/miniconda3/envs/rstr_vctr/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1665         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1666         for line in lines:
# -> 1667             self.add_line(line)
#    1668         self.autoscale_view(scalex=scalex, scaley=scaley)
# ...
